# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as pp
from  sklearn import preprocessing
# %matplotlib inline

# %%
#loading data
data=pd.read_excel('data_complete_shuffled.xls')
data
# Out:
#                  Crop  year  Area Harvested - Ha  \
# 0.000000        grape  1993               6000.0
# 1.000000         rice  1978            6300000.0
# 2.000000       barley  1985              70000.0
# 3.000000       tomato  1963             434000.0
# 4.000000    pineapple  1998           12572000.0
# 5.000000          tea  2003              39825.0
# 6.000000          tea  1993             150000.0
# 7.000000    pineapple  1963             111000.0
# 8.000000       banana  1971              45977.0
# 9.000000       banana  1980            1482800.0
# 10.000000       grape  1999            4054900.0
# 11.000000      barley  1999           15958100.0
# 12.000000      potato  1991             475300.0
# 13.000000      tomato  1974            3439000.0
# 14.000000      barley  2003               4600.0
# 15.000000      banana  1968            5583400.0
# 16.000000   green_pea  1972            3151100.0
# 17.000000   sugarcane  1979             353359.0
# 18.000000         tea  1988           41244000.0
# 19.000000       wheat  1962             332524.0
# 20.000000   sugarcane  1965               5100.0
# 21.000000   pineapple  1998             444000.0
# 22.000000        rice  1969              36579.0
# 23.000000       grape  1999            1030400.0
# 24.000000      potato  1990              39500.0
# 25.000000      ginger  1976              50000.0
# 26.000000   pineapple  1995            7430400.0
# 27.000000       grape  1968            3840000.0
# 28.000000      potato  1982              34900.0
# 29.000000   pineapple  2003             270000.0
# ...               ...   ...                  ...
# 643.000000  sugarcane  1977            2764900.0
# 644.000000     banana  1985            1224700.0
# 645.000000      wheat  1967              23000.0
# 646.000000     barley  1990              63647.0
# 647.000000  pineapple  1970            1069400.0
# 648.000000      maize  1995             398453.0
# 649.000000     potato  1983            3357600.0
# 650.000000  pineapple  1987              43950.0
# 651.000000     potato  1986             490000.0
# 652.000000      grape  1976           23261904.0
# 653.000000  green_pea  1988               9822.0
# 654.000000  sugarcane  2006             849000.0
# 655.000000       rice  2001            5797200.0
# 656.000000     papaya  1973             962200.0
# 657.000000     barley  1979           23567408.0
# 20.000000    madrchod  2000                  NaN
# 16.000000    madrchod  2001                  NaN
# 19.799999    madrchod  2002                  NaN
# 18.400000    madrchod  2003                  NaN
# 17.100000    madrchod  2004                  NaN
# 15.500000    madrchod  2005                  NaN
# 14.700000    madrchod  2006                  NaN
# 17.100000    madrchod  2007                  NaN
# 15.400000    madrchod  2008                  NaN
# 16.200001    madrchod  2009                  NaN
# 15.000000    madrchod  2010                  NaN
# 17.200001    madrchod  2011                  NaN
# 16.000000    madrchod  2012                  NaN
# 17.000000    madrchod  2013                  NaN
# 14.400000    madrchod  2014                  NaN
#
#             Production Quantity - tonnes  Yield - Hg/Ha
# 0.000000                       1200000.0   18432.000000
# 1.000000                      73352000.0   19623.000000
# 2.000000                     104225008.0  258628.000000
# 3.000000                      24734608.0  343061.000000
# 4.000000                        246806.0  137248.000000
# 5.000000                        201600.0  661458.000000
# 6.000000                     225569200.0   81301.000000
# 7.000000                     140603504.0  123639.000000
# 8.000000                         37910.0   10611.000000
# 9.000000                      72156200.0   19972.000000
# 10.000000                       660000.0   16279.000000
# 11.000000                      1500000.0   97000.000000
# 12.000000                     20857800.0   28911.000000
# 13.000000                       559583.0   26789.000000
# 14.000000                       236000.0  100000.000000
# 15.000000                     44322896.0   11585.000000
# 16.000000                      3190000.0   19995.000000
# 17.000000                       232500.0  109038.000000
# 18.000000                      2420000.0  146335.000000
# 19.000000                        38460.0    8795.000000
# 20.000000                       418517.0  160919.000000
# 21.000000                    124676096.0  109289.000000
# 22.000000                      1474800.0   23266.000000
# 23.000000                      1901200.0   17969.000000
# 24.000000                       800000.0  139204.000000
# 25.000000                     49849504.0   16884.000000
# 26.000000                      2298700.0  224124.000000
# 27.000000                        86980.0  277910.000000
# 28.000000                       703900.0   10943.000000
# 29.000000                       408510.0  142857.000000
# ...                                  ...            ...
# 643.000000                      560000.0   18325.000000
# 644.000000                     4600000.0   20588.000000
# 645.000000                      593230.0   20405.000000
# 646.000000                     1050000.0  509327.000000
# 647.000000                    12043200.0   10865.000000
# 648.000000                     2784400.0   74403.000000
# 649.000000                     1060000.0  153220.000000
# 650.000000                    59840000.0  142045.000000
# 651.000000                    37451808.0   17921.000000
# 652.000000                    44068800.0   26971.000000
# 653.000000                     1900000.0   10000.000000
# 654.000000                      478271.0   16094.000000
# 655.000000                    24104400.0  222274.000000
# 656.000000                   203036800.0   10699.000000
# 657.000000                    15205600.0   19579.000000
# 20.000000                            NaN      88.599998
# 16.000000                            NaN      71.599998
# 19.799999                            NaN      93.300003
# 18.400000                            NaN      84.300003
# 17.100000                            NaN      80.599998
# 15.500000                            NaN      75.199997
# 14.700000                            NaN      69.699997
# 17.100000                            NaN      82.000000
# 15.400000                            NaN      69.400002
# 16.200001                            NaN      83.300003
# 15.000000                            NaN      79.599998
# 17.200001                            NaN      82.599998
# 16.000000                            NaN      80.599998
# 17.000000                            NaN      83.500000
# 14.400000                            NaN      76.300003
#
# [673 rows x 5 columns]

# %%
#prediction will be done according to different crops as one will not 
#depend on other and hence distort the graph for others.
crop_name='papaya' #let, this variable will be used always
#filter data according to crop_name
data=data.loc[data['Crop']==crop_name]
#now sorted so that we could only take last 10 years to predict next
data=data.sort_values(by='year',ascending=True).drop('Crop',axis=1).drop('Production Quantity - tonnes',axis=1).drop('year',axis=1)
data.tail()
# Out:
#        Area Harvested - Ha  Yield - Hg/Ha
# 443.0              10830.0        15079.0
# 237.0            2953200.0        17614.0
# 213.0            1401400.0        89062.0
# 469.0              87200.0       125000.0
# 501.0             282000.0        91428.0

# %%
#NOT NEEDED as we have filtered above according to crop and removed 'Crop' column

# #creating labelEncoder
# encoder=preprocessing.LabelEncoder()#creating object
# encoder.fit(data['Crop'])#fitting 'string labels' with encode as integers
# #transform - convert string to number, inverse_transform -convert number to string
# X['crop']=encoder.transform(data['Crop'])
# #encoder.inverse_transform(0)
# #removing the X['Crop'] column
# X.drop(inplace=True,axis=1,labels='Crop')

# %%
model=LinearRegression()

# %%
X,y=data.iloc[:,0:-1],data.iloc[:,-1:]
X# all columns other than last
y#only last column, Yeild
# Out:
#        Yield - Hg/Ha
# 560.0         8267.0
# 510.0        33029.0
# 435.0        13232.0
# 206.0       145555.0
# 192.0        10814.0
# 618.0        84409.0
# 384.0        11687.0
# 578.0       561597.0
# 37.0         16922.0
# 576.0        11719.0
# 656.0        10699.0
# 174.0        92105.0
# 441.0       191666.0
# 359.0        19000.0
# 184.0       150285.0
# 494.0        16848.0
# 321.0         8787.0
# 88.0        145270.0
# 107.0       161393.0
# 39.0        162539.0
# 353.0        18216.0
# 593.0       380000.0
# 614.0        18158.0
# 440.0        20002.0
# 602.0       475106.0
# 250.0       109090.0
# 464.0        11719.0
# 579.0       178801.0
# 559.0        85000.0
# 247.0         8015.0
# 60.0          9644.0
# 44.0        237897.0
# 583.0        12951.0
# 249.0        33917.0
# 228.0        10099.0
# 604.0        31537.0
# 360.0       166666.0
# 452.0        18097.0
# 152.0       108635.0
# 182.0       135579.0
# 490.0        19612.0
# 220.0       120665.0
# 443.0        15079.0
# 237.0        17614.0
# 213.0        89062.0
# 469.0       125000.0
# 501.0        91428.0

# %%
Xdas=X.iloc[-10:-5]
ydas=y.iloc[-10:-5]#last 10
ydas
# Out:
#        Yield - Hg/Ha
# 452.0        18097.0
# 152.0       108635.0
# 182.0       135579.0
# 490.0        19612.0
# 220.0       120665.0

# %%
"""
as fit() method can't use 'string' and out "Crop" column has string so we have to transform into intergers
method 1 - find number of classes and assign unique id manually
method 2 - let python do that for us ,using 'labelEncoder' class
"""
model.fit(Xdas,ydas)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
#model.score(X[-5:],y[-5:])

# %%
pp.plot([i+1961 for i in range(42)],y.iloc[:-5])
pp.plot([i+2002 for i in range(5)],y.iloc[-5:])
pp.plot([i+2002 for i in range(5)],model.predict(X.iloc[-5:]))
pp.legend(['Trainig Data','Testing Data','Predicted Data','Plotted Line'])
#fuction for plottin line using equation
def graph(formula, x_range):  
    x = np.array(x_range)  
    y = eval(formula)
    pp.plot(x, y)  
    pp.show()
graph('-0.0010307*x+96645.9754983',range(1961,2007))

# %%
model.intercept_,model.coef_
# Out:
# (array([ 69076.41530143]), array([[ 0.01422743]]))

# %%
model.predict(X.iloc[-5:])
# Out:
# array([[  69230.49841373],
#        [ 111092.87395713],
#        [  89014.74157804],
#        [  70317.04756297],
#        [  73088.55174356]])
